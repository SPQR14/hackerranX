# %%
celcius = range(-100,101)
farenheit = [((9/5)* temp + 32) for temp in celcius if temp % 2 == 0]

# %%
for x in zip(celcius, farenheit):
    print(x)
# Out:
# (-100, -148.0)
# (-99, -144.4)
# (-98, -140.8)
# (-97, -137.20000000000002)
# (-96, -133.6)
# (-95, -130.0)
# (-94, -126.4)
# (-93, -122.80000000000001)
# (-92, -119.20000000000002)
# (-91, -115.6)
# (-90, -112.0)
# (-89, -108.4)
# (-88, -104.80000000000001)
# (-87, -101.20000000000002)
# (-86, -97.6)
# (-85, -94.0)
# (-84, -90.4)
# (-83, -86.8)
# (-82, -83.2)
# (-81, -79.60000000000001)
# (-80, -76.0)
# (-79, -72.4)
# (-78, -68.8)
# (-77, -65.2)
# (-76, -61.60000000000001)
# (-75, -58.0)
# (-74, -54.400000000000006)
# (-73, -50.8)
# (-72, -47.2)
# (-71, -43.60000000000001)
# (-70, -40.0)
# (-69, -36.400000000000006)
# (-68, -32.8)
# (-67, -29.200000000000003)
# (-66, -25.6)
# (-65, -22.0)
# (-64, -18.4)
# (-63, -14.800000000000004)
# (-62, -11.200000000000003)
# (-61, -7.600000000000001)
# (-60, -4.0)
# (-59, -0.3999999999999986)
# (-58, 3.1999999999999993)
# (-57, 6.800000000000001)
# (-56, 10.399999999999999)
# (-55, 14.0)
# (-54, 17.6)
# (-53, 21.2)
# (-52, 24.8)
# (-51, 28.4)
# ...

# %%
ambos = list(zip(celcius,farenheit))

# %%
ambos
# Out:
# [(-100, -148.0),
#  (-99, -146.20000000000002),
#  (-98, -144.4),
#  (-97, -142.6),
#  (-96, -140.8),
#  (-95, -139.0),
#  (-94, -137.20000000000002),
#  (-93, -135.4),
#  (-92, -133.6),
#  (-91, -131.8),
#  (-90, -130.0),
#  (-89, -128.20000000000002),
#  (-88, -126.4),
#  (-87, -124.6),
#  (-86, -122.80000000000001),
#  (-85, -121.0),
#  (-84, -119.20000000000002),
#  (-83, -117.4),
#  (-82, -115.6),
#  (-81, -113.80000000000001),
#  (-80, -112.0),
#  (-79, -110.20000000000002),
#  (-78, -108.4),
#  (-77, -106.6),
#  (-76, -104.80000000000001),
#  (-75, -103.0),
#  (-74, -101.20000000000002),
#  (-73, -99.4),
#  (-72, -97.6),
#  (-71, -95.8),
#  (-70, -94.0),
#  (-69, -92.2),
#  (-68, -90.4),
#  (-67, -88.60000000000001),
#  (-66, -86.8),
#  (-65, -85.0),
#  (-64, -83.2),
#  (-63, -81.4),
#  (-62, -79.60000000000001),
#  (-61, -77.8),
#  (-60, -76.0),
#  (-59, -74.2),
#  (-58, -72.4),
#  (-57, -70.60000000000001),
#  (-56, -68.8),
#  (-55, -67.0),
#  (-54, -65.2),
# ...

# %%
algo = input("Por favor, ingresa tu sueldo después de impuestos con todo y centavos:  ")
# Out:
# Por favor, ingresa tu sueldo después de impuestos con todo y centavos:  987987979

# %%
algo
# Out:
# '987987979'
